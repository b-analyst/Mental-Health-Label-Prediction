# %%
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk import FreqDist

col = ['text']
df_old = pd.read_csv('bipolar_forum.csv', names=col, header=None)
df = pd.DataFrame({'text': df_old['text'],
                   'label': 4})
df.fillna(value='')

###tokenize title and body texts###
tokenizer = RegexpTokenizer(r'\w+')
df['text'] = df['text'].apply(lambda x: tokenizer.tokenize(str(x).lower()))


###remove stopwords###

#returns all words that aren't in the list of stopwords
def remove_stopwords(text):
    words = [w for w in text if w not in stopwords.words('english')]
    return words
#had to use 'python -m nltk.downloader stopwords' from the TestEnv to make stopwords work
df['text'] = df['text'].apply(lambda x: remove_stopwords(x))


###lemmatizer -- lemmatizer maps common words back to its base###

lemmatizer = WordNetLemmatizer()

def word_lemmatizer(text):
    lem_text = [lemmatizer.lemmatize(x) for x in text]
    return lem_text
df['text'] = df['text'].apply(lambda x: word_lemmatizer(x))


###storing title and body columns as a list to feed into pos_tag###
title_list = list(df['text'])



#Text classification: pos tagging
pos_tagged_text = []

for ele in title_list:
    pos_tagged_text.append(nltk.pos_tag(ele))

    
df['pos_tagged_text'] = pos_tagged_text



###The codes below analyzes text frequency distribution, collocation, and concordance while excluding certain words###
single_w = []
exclude_list = ['www', 'mentalhealthforum', 'net', 'com', 'http', 'nan']

def exclude(text):
    words = [w for w in text if w not in exclude_list]
    return words
df['text'] = df['text'].apply(lambda x: exclude(x))

for item in df['pos_tagged_text']:
    for tuples in item:
        if tuples[0] not in exclude_list:
            single_w.append(tuples[0])

            
fd = nltk.FreqDist(single_w)
print(fd.most_common(20))


text = nltk.Text(single_w)
concordance_list = text.concordance_list("want", lines=20)
for entry in concordance_list:
    print(entry.line)
finder = nltk.collocations.QuadgramCollocationFinder.from_words(text)
print(finder)
print(finder.ngram_fd.most_common(20))


'''creating a dictionary to store counts of unique POS tags''' 
pos_list = []
for row in df['pos_tagged_text']:
    for tup in row:
        if tup[1] not in pos_list:
            pos_list.append(tup[1])
            
pos_dict = {}
for item in pos_list:
    pos_dict[item] = 0
    for row in df['pos_tagged_text']:
        for tup in row:
            if tup[1] == item:
                pos_dict[item] += 1
                

'''Plotting the counts'''
# %matplotlib inline

fig = plt.figure(figsize=(15,10))
plt.bar(pos_dict.keys(), pos_dict.values(), color='red')
plt.tight_layout()
plt.savefig("pos_dist.png", dpi=300)
plt.show()


df_new = pd.DataFrame({'text': df['text'],
                       'label': 4})


df_new.to_csv('bipolar_forum_clean.csv', index=False)
# Out:
# [('like', 2509), ('feel', 2419), ('time', 1938), ('know', 1751), ('get', 1743), ('bipolar', 1567), ('year', 1526), ('day', 1449), ('want', 1409), ('thing', 1403), ('really', 1214), ('would', 1207), ('people', 1168), ('life', 1156), ('one', 1146), ('go', 1114), ('even', 1026), ('think', 1025), ('going', 923), ('thought', 909)]
# ment get live alone feel like people want substance reach self imposed perspec
# rkey still issue needed resolve told want talk anymore mental health explained
#  behavior bipolar person really mean want end thing ever since got diagnosed d
# ip im finding increasingly difficult want near people im finding existence emb
# l adamant divorcing coming back home want come visit take care thing pack car
# thing wrong excited visit point even want making feel sad scared awkward home
# t along dealing trauma grief divorce want want act like buddy nothing wrong am
# ng dealing trauma grief divorce want want act like buddy nothing wrong amicabl
#  amicably splitting infuriating mean want talk work 17 year even gone one coun
# ear even gone one counseling session want come pack thing take care logistics
# hoice stay whats point even come say want talk happened person though phone fe
# g going fit rage trouble controlling want go hospital sure also mom important
# hing need able take care good mother want able go enjoy thing life function in
# e appointment tomorrow thinking make want throw gotten way worse covid driving
#  day getting take vicodin tooth dont want clozapine inter fear would anyone kn
# le keep literally ruining everything want go school career home family feel ho
#  starting keepgoing onandonand onand want stop im tired one understands litera
#  yr old 16 pound terrier lazy doesnt want mile used hoping old friend well ple
#  hi wondering got diagnosed gp seems want medicate leave referred emotional we
# mictal good depressive episode manic want take something calm zombify cause we
# <nltk.collocations.QuadgramCollocationFinder object at 0x0000025DB7A36408>
# [(('low', 'low', 'low', 'low'), 43), (('cry2', 'cry2', 'cry2', 'cry2'), 31), (('advice', 'would', 'greatly', 'appreciated'), 8), (('recently', 'diagnosed', 'bipolar', 'disorder'), 6), (('feel', 'like', 'going', 'crazy'), 5), (('anyone', 'else', 'feel', 'like'), 5), (('hi', 'everyone', 'first', 'post'), 5), (('diagnosed', 'bipolar', 'type', '1'), 5), (('hi', 'everyone', 'new', 'forum'), 5), (('scared', 'scared', 'scared', 'scared'), 5), (('anyone', 'else', 'feel', 'way'), 4), (('diagnosed', 'borderline', 'personality', 'disorder'), 4), (('would', 'greatly', 'appreciated', 'thanks'), 4), (('one', 'day', 'next', 'day'), 4), (('full', 'blown', 'manic', 'episode'), 4), (('best', 'thing', 'ever', 'happened'), 4), (('recently', 'diagnosed', 'bipolar', 'ii'), 3), (('diagnosed', '2', 'year', 'ago'), 3), (('type', '1', 'ptsd', 'delayed'), 3), (('1', 'ptsd', 'delayed', 'expression'), 3)]

# %%
from wordcloud import WordCloud, ImageColorGenerator
'''defining method to generate a WordCloud'''
def generate_wordcloud(data, title):
    cloud = WordCloud(width=400,
                      height=330,
                      max_words=150,
                      colormap='tab20c',
                      stopwords=exclude_list,
                      collocations=False,
                      background_color='white'
                     ).generate_from_text(data)
    plt.figure(figsize=(14,10))
    plt.imshow(cloud)
    plt.axis('off')
    plt.title(title, fontsize=13)
    plt.savefig("wordcloud.png", dpi=300)
    plt.show()
    
generate_wordcloud(str(single_w), 'Bipolar Corpus')

# %%
top_20 = []
w_freq = fd.most_common(20)

freq_dist = dict(w_freq)
fig = plt.figure(figsize=(14,10))
plt.plot(freq_dist.keys(), freq_dist.values(), color='b')
plt.title("Frequencies of 20 Most Common Words - Bipolar Forum Site")
plt.xlabel("Words")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

plt.savefig("forum.png", dpi=300)
